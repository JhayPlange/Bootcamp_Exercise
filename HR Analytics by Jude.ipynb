# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("J:\people.csv")

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df["left"].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
df["promotionInLast5years"].value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotionInLast5years, dtype: int64

# %%
df["salary"].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
# dealing with null values
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.head(50)
# Out:
#     satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                0.38            0.53                 2              157
# 1                0.80            0.86                 5              262
# 2                0.11            0.88                 7              272
# 3                0.37            0.52                 2              159
# 4                0.41            0.50                 2              153
# 5                0.10            0.77                 6              247
# 6                0.92            0.85                 5              259
# 7                0.42            0.53                 2              142
# 8                0.45            0.54                 2              135
# 9                0.11            0.81                 6              305
# 10               0.36            0.56                 2              137
# 11               0.38            0.54                 2              143
# ...

# %%
# checking the outliers
plt.boxplot(df["avgMonthlyHours"])
plt.show()

# %%
df.tail(50)
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14925               0.82            0.84                 3              237
# 14927               0.88            0.62                 4              237
# 14928               0.14            0.74                 4              117
# 14929               0.55            0.49                 3              205
# 14931               0.22            0.90                 4              209
# 14932               0.26            0.71                 6              189
# 14934               0.47            0.44                 5              255
# 14935               0.83            0.98                 4              254
# 14936               0.58            0.76                 3              220
# 14937               0.25            0.69                 3              187
# 14939               0.56            0.81                 3              165
# ...

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype!="object":
        plt.boxplot(df[col])
        plt.xlabel(col) 
        plt.show()

# %% [markdown]
# # Inferences from the data

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x="numberOfProjects",hue="left")
plt.show()

# %%
# Inference: People with number of project 2 and 7 are leaving the most
# Suggestions: All employees should be assigned 3-5 projects on an average
#              Should re- distribute projects of employees workinmg on 7 projects to the the emplyees working
#              on 2 projects

# %%
 plt.figure(figsize=(10,5))
 sns.histplot(data=df,x="avgMonthlyHours",hue="left")
 plt.show()

# %%
data=df.copy()

# %%
data["avgMonthlyHours"].mean()
# Out:
# 200.4735218080227

# %%
data[data["avgMonthlyHours"]>200].groupby("left").count()
# Out:
#       satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# left
# 0                  4865            4865              4865             4865
# 1                  1081            1081              1081             1081
#
#       timeSpent.company  workAccident  promotionInLast5years  dept  salary
# left
# 0                  4865          4865                   4865  4865    4865
# 1                  1081          1081                   1081  1081    1081

# %%
data[data["avgMonthlyHours"]<200].groupby("left").count()
# Out:
#       satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# left
# 0                  5082            5082              5082             5082
# 1                   910             910               910              910
#
#       timeSpent.company  workAccident  promotionInLast5years  dept  salary
# left
# 0                  5082          5082                   5082  5082    5082
# 1                   910           910                    910   910     910

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x="timeSpent.company",hue="left")
plt.show()

# %%
# Inference= People leave the organisation after exp of 3 -5 years
# Suggestions:
#            Once they complete 3-5 years, then they should be given supervisory roles for projects with inexperienced ones working under them
#            giving the role based incentives or increments

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x="workAccident",hue="left")
plt.show()

# %%
# Work accidents are not relevent reasons for leaving the organization
# Inference = Employees are not leaving just because of conflicts
# Suggestion -- Nill

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x="promotionInLast5years",hue="left")
plt.show()

# %%
# Inference : People who are not having promotions in last 5 year are leaving
# Suggetions: HRs should provide time to time promotions to the employees

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x="dept",hue="left")
plt.show()

# %%
# Inference = People of sales, technical, support are leaving the company most

# suggesions=
# 1.give option to move other departments
# 2. incentives
# 3. for better team management, team meetings to discuss whatever problem employees are facing
# 4.taking the team for outings, lunch, for recreational activity and reduce stress level

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x="salary",hue="left")
plt.show()

# %%
# Inferecences - EWmployees with low/medium salary are leaving most
# Suggestions:
#  Regular salary hikes according to the experience and based on market values
# salary hikes + promotion + incentives+ perks
