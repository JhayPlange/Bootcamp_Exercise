# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("J:\cars-1 (2).csv")

# %%
data
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
data["weightlbs"]=pd.to_numeric(data["weightlbs"],errors="coerce")
data["cubicinches"]=pd.to_numeric(data["cubicinches"],errors="coerce")

# %% [markdown]
# # Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60) with respect to each brand.

# %% [markdown]
# # Scatter plot for mpg and hp

# %%
sns.scatterplot(data=data, x="mpg", y="hp")
# Out:
# <Axes: xlabel='mpg', ylabel='hp'>

# %%
plt.scatter(data["mpg"],data["hp"])

# %%
plt.figure(figsize=(10,5))
plt.scatter(data["mpg"],data["weightlbs"])

# %%
sns.scatterplot(data=data, x="mpg", y="weightlbs")
# Out:
# <Axes: xlabel='mpg', ylabel='weightlbs'>

# %%
plt.scatter(data["mpg"],data["weightlbs"])

# %%
sns.scatterplot(data=data, x="hp", y="mpg")
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
plt.scatter(data["hp"],data["time-to-60"])

# %%
sns.scatterplot(data=data, x="hp", y="time-to-60")
# Out:
# <Axes: xlabel='hp', ylabel='time-to-60'>

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.scatter(data["mpg"],data["hp"])
plt.subplot(2,2,2)
plt.scatter(data["mpg"],data["weightlbs"])
plt.subplot(2,2,3)
plt.scatter(data["hp"],data["mpg"])
plt.subplot(2,2,4)
plt.scatter(data["hp"],data["time-to-60"])
plt.show()

# %% [markdown]
# # Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.

# %%
data
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year     brand
# 0    14.0          8        350.0  165     4209.0          12  1972       US.
# 1    31.9          4         89.0   71     1925.0          14  1980   Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971       US.
# 3    15.0          8        400.0  150     3761.0          10  1971       US.
# 4    30.5          4         98.0   63     2051.0          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8        305.0  130     3840.0          15  1980       US.
# 257  36.1          4         91.0   60     1800.0          16  1979    Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983       US.
# 259  18.0          6        232.0  100     3288.0          16  1972       US.
# 260  22.0          6        250.0  105     3353.0          15  1977       US.
#
# [261 rows x 8 columns]

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.barplot(data=data, x="cylinders", y="hp", hue="brand")
plt.subplot(2,2,2)
sns.barplot(data=data, x="cylinders", y="mpg", hue="brand")
plt.subplot(2,2,3)
sns.barplot(data=data, x="cylinders", y="weightlbs", hue="brand")
plt.subplot(2,2,4)
sns.barplot(data=data, x="cylinders", y="time-to-60", hue="brand")
plt.show()

# %% [markdown]
# # Create a bar plot that shows the visual representation of hp, mpg, weight and time-to-60 with respect to the years, for each brand.

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.barplot(data=data, x="year", y="hp", hue="brand")
plt.subplot(2,2,2)
sns.barplot(data=data, x="year", y="mpg", hue="brand")
plt.subplot(2,2,3)
sns.barplot(data=data, x="year", y="weightlbs", hue="brand")
plt.subplot(2,2,4)
sns.barplot(data=data, x="year", y="time-to-60", hue="brand")
plt.show()
# Out:
# J:\New folder\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %% [markdown]
# # Create box plots for the columns in the step1 with respect to the number of cylinders and brand respectively.

# %%
plt.boxplot(data["hp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c41522c20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c41523160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c41522980>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c41523670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c41523910>],
#  'means': []}

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.boxplot(data=data, x="cylinders", y="hp", hue="brand")
plt.subplot(2,2,2)
sns.boxplot(data=data, x="cylinders", y="mpg", hue="brand")
plt.subplot(2,2,3)
sns.boxplot(data=data, x="cylinders", y="weightlbs", hue="brand")
plt.subplot(2,2,4)
sns.boxplot(data=data, x="cylinders", y="time-to-60", hue="brand")
plt.show()

# %% [markdown]
# # Create pair plots for the entire data to study various patterns in the data. Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="brand")

# %%
sns.pairplot(data, hue="year")

# %% [markdown]
# # Create a heatmap for the entire data to study correlation between each of the columns.

# %%
data.corr()
# Out:
# C:\Users\spencer\AppData\Local\Temp\ipykernel_11552\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776710    -0.803964 -0.774905  -0.825234
# cylinders   -0.776710   1.000000     0.951452  0.845155   0.896093
# cubicinches -0.803964   0.951452     1.000000  0.906902   0.930027
# hp          -0.774905   0.845155     0.906902  1.000000   0.861028
# weightlbs   -0.825234   0.896093     0.930027  0.861028   1.000000
# time-to-60   0.509070  -0.578161    -0.613199 -0.744873  -0.480772
# year         0.550441  -0.322239    -0.350293 -0.383869  -0.281119
#
#              time-to-60      year
# mpg            0.509070  0.550441
# cylinders     -0.578161 -0.322239
# ...

# %%
sns.heatmap(data.corr())
# Out:
# C:\Users\spencer\AppData\Local\Temp\ipykernel_11552\1794321463.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# C:\Users\spencer\AppData\Local\Temp\ipykernel_11552\1119197534.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <Axes: >

# %%
sns.heatmap(data.corr(),annot=True,cmap="Greens")
# Out:
# C:\Users\spencer\AppData\Local\Temp\ipykernel_11552\574871046.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap="Greens")
# <Axes: >

# %% [markdown]
# # Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with respect to brand

# %%
data
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year     brand
# 0    14.0          8        350.0  165     4209.0          12  1972       US.
# 1    31.9          4         89.0   71     1925.0          14  1980   Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971       US.
# 3    15.0          8        400.0  150     3761.0          10  1971       US.
# 4    30.5          4         98.0   63     2051.0          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8        305.0  130     3840.0          15  1980       US.
# 257  36.1          4         91.0   60     1800.0          16  1979    Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983       US.
# 259  18.0          6        232.0  100     3288.0          16  1972       US.
# 260  22.0          6        250.0  105     3353.0          15  1977       US.
#
# [261 rows x 8 columns]

# %%
plt.hist(data["mpg"])
plt.xlabel("mpg")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
for col in data.columns:
    if col!="brand":
        plt.hist(data[col])
        plt.xlabel(col)
        plt.show()

# %% [markdown]
# # Create line plots for the following: Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight lbs, mpg-weight lbs, cubic inches-weight lb

# %%
plt.plot(data["hp"],data["mpg"])
plt.xlabel("hp")
plt.ylabel("mpg")
plt.show()

# %%
sns.lineplot(data=data,x="hp",y="mpg")
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
sns.lineplot(data=data,x="hp",y="time-to-60")
# Out:
# <Axes: xlabel='hp', ylabel='time-to-60'>

# %% [markdown]
# # Create a pie chart for the following columns and their distribution in the data: a: Brands

# %%
counts=data["brand"].value_counts()
counts
# Out:
#  US.        162
#  Japan.      51
#  Europe.     48
# Name: brand, dtype: int64

# %%
val=counts.values
val
# Out:
# array([162,  51,  48], dtype=int64)

# %%
l=counts.index
l
# Out:
# Index([' US.', ' Japan.', ' Europe.'], dtype='object')

# %%
plt.pie(val,labels=l)
plt.show()

# %%
plt.pie(val,labels=l,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# # Create violin plots for the following: it shows the density
# # a. hp, mpg, time-to-60, with respect to the number of cylinders for each brand.

# %%
sns.violinplot(data=data,x="cylinders",y="hp", hue="brand")
# Out:
# <Axes: xlabel='cylinders', ylabel='hp'>

# %%
sns.violinplot(data=data,x="cylinders",y="mpg", hue="brand")
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
sns.violinplot(data=data,x="cylinders",y="time-to-60", hue="brand")
# Out:
# <Axes: xlabel='cylinders', ylabel='time-to-60'>

# %% [markdown]
# # Create categorical plots for the following:
# # a. Hp, mpg, time-to-60, weight, cubic inches, with respect to each brand for various numbers of cylinders

# %%
sns.catplot(data=data,x="cylinders",y="hp", hue="brand")

# %% [markdown]
# # Create the area charts for the following:
# # a. Mpg with respect to each brand of the car

# %%
sns.histplot(data=data,x="mpg", element="poly", hue="brand")
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>
